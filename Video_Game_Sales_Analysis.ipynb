# %% [markdown]
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align: center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Libraries</strong>
#   </h1>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align: center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Video Game Sales Analysis</strong>
#   </h1>
# </div>

# %% [markdown]
# <div style="position: relative; display: inline-block;">
#
#   <!-- Background/Main Image -->
#   <img src= "https://images.unsplash.com/photo-1593305841991-05c297ba4575?q=80&w=1957&auto=format&fit=crop&ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D" style="width: 1000px;">

# %% [markdown]
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align: center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Exploratory Data Analysis</strong>
#   </h1>
# </div>

# %%
video_game_sale = pd.read_csv(r"D:\python\Pandas Unguided Project\vgsalesdataset.csv")

# %%
video_game_sale
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
video_game_sale_dict = pd.read_csv(r"D:\python\Pandas Unguided Project\Video_Game_data_dict.csv")

# %%
video_game_sale_dict
# Out:
#            Field                                        Description  \
# 0           Rank                           Ranking of overall sales
# 1           Name                                     The games name
# 2       Platform  Platform of the games release (i.e. PC,PS4, etc.)
# 3           Year                         Year of the game's release
# 4          Genre                                  Genre of the game
# 5      Publisher                              Publisher of the game
# 6       NA_Sales               Sales in North America (in millions)
# 7       EU_Sales                      Sales in Europe (in millions)
# 8       JP_Sales                       Sales in Japan (in millions)
# 9    Other_Sales       Sales in the rest of the world (in millions)
# 10  Global_Sales                             Total worldwide sales.
#
#     Unnamed: 2
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# ...

# %%
video_game_sale_dict.drop("Unnamed: 2", axis = 1, inplace = True)

# %%
video_game_sale_dict
# Out:
#            Field                                        Description
# 0           Rank                           Ranking of overall sales
# 1           Name                                     The games name
# 2       Platform  Platform of the games release (i.e. PC,PS4, etc.)
# 3           Year                         Year of the game's release
# 4          Genre                                  Genre of the game
# 5      Publisher                              Publisher of the game
# 6       NA_Sales               Sales in North America (in millions)
# 7       EU_Sales                      Sales in Europe (in millions)
# 8       JP_Sales                       Sales in Japan (in millions)
# 9    Other_Sales       Sales in the rest of the world (in millions)
# 10  Global_Sales                             Total worldwide sales.

# %%
import warnings
warnings.filterwarnings("ignore")
# to ignore warnings

# %% [markdown]
# #
#
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align: center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Checking If There Are Missing Values In The Dataset</strong>
#   </h1>
# </div>

# %%
video_game_sale.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
video_game_sale.shape
# Out:
# (16598, 11)

# %%
video_game_sale.dropna(how = "any", inplace = True)

# %%
video_game_sale
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
video_game_sale.reset_index(drop = True, inplace = True)

# %%
video_game_sale.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
video_game_sale.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
video_game_sale.shape
# Out:
# (16291, 11)

# %% [markdown]
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align: center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Information About The Dataset</strong>
#   </h1>
# </div>

# %%
video_game_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16291 entries, 0 to 16290
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
video_game_sale["Year"] = video_game_sale["Year"].astype(int)
# converting year column from float to int

# %%
video_game_sale.head()
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align: center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Video Game Sales Analysis</strong>
#   </h1>
# </div>

# %%
video_game_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16291 entries, 0 to 16290
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  int64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
video_game_sale.head()
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
video_game_sale.describe().round(2)
# Out:
#            Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# count  16291.00  16291.00  16291.00  16291.00  16291.00     16291.00
# mean    8290.19   2006.41      0.27      0.15      0.08         0.05
# std     4792.65      5.83      0.82      0.51      0.31         0.19
# min        1.00   1980.00      0.00      0.00      0.00         0.00
# 25%     4132.50   2003.00      0.00      0.00      0.00         0.00
# 50%     8292.00   2007.00      0.08      0.02      0.00         0.01
# 75%    12439.50   2010.00      0.24      0.11      0.04         0.04
# max    16600.00   2020.00     41.49     29.02     10.22        10.57
#
#        Global_Sales
# count      16291.00
# mean           0.54
# std            1.57
# min            0.01
# 25%            0.06
# 50%            0.17
# 75%            0.48
# max           82.74

# %%
video_game_sale.describe(include = "object")
# Out:
#                                Name Platform   Genre        Publisher
# count                         16291    16291   16291            16291
# unique                        11325       31      12              576
# top     Need for Speed: Most Wanted       DS  Action  Electronic Arts
# freq                             12     2131    3251             1339

# %%
video_game_sale.duplicated().sum()
# Out:
# np.int64(0)

# %%
video_game_sale.rename(columns = {
    "NA_Sales":"North_America_Sales",
    "EU_Sales":"Europe_Sales",
    "JP_Sales":"Japan_Sales"
}, inplace = True)
# Renaming Columns

# %%
video_game_sale.head()
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    North_America_Sales  Europe_Sales  Japan_Sales  Other_Sales  Global_Sales
# 0                41.49         29.02         3.77         8.46         82.74
# 1                29.08          3.58         6.81         0.77         40.24
# 2                15.85         12.88         3.79         3.31         35.82
# 3                15.75         11.01         3.28         2.96         33.00
# 4                11.27          8.89        10.22         1.00         31.37

# %% [markdown]
# #
#
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align: center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Finding Average Sales Of Video Games Per Genre In Regions</strong>
#   </h1>
# </div>

# %%
avg_sales_per_genre_in_na = video_game_sale.groupby('Genre')['North_America_Sales'].mean()

# %%
avg_sales_per_genre_in_na
# Out:
# Genre
# Action          0.265078
# Adventure       0.080008
# Fighting        0.264043
# Misc            0.235421
# Platform        0.509703
# Puzzle          0.214053
# Racing          0.291371
# Role-Playing    0.222109
# Shooter         0.448643
# Simulation      0.214363
# Sports          0.290838
# Strategy        0.101239
# Name: North_America_Sales, dtype: float64

# %%
avg_sales_per_genre_in_europe = video_game_sale.groupby('Genre')['Europe_Sales'].mean()

# %%
avg_sales_per_genre_in_europe
# Out:
# Genre
# Action          0.158868
# Adventure       0.050031
# Fighting        0.119617
# Misc            0.125605
# Platform        0.229314
# Puzzle          0.088632
# Racing          0.192906
# Role-Playing    0.127599
# Shooter         0.242161
# Simulation      0.133278
# Sports          0.161172
# Strategy        0.066925
# Name: Europe_Sales, dtype: float64

# %%
avg_sales_per_genre_in_japan = video_game_sale.groupby('Genre')['Japan_Sales'].mean()

# %%
avg_sales_per_genre_in_japan
# Out:
# Genre
# Action          0.048800
# Adventure       0.040808
# Fighting        0.104246
# Misc            0.063268
# Platform        0.149314
# Puzzle          0.099439
# Racing          0.046212
# Role-Playing    0.238293
# Shooter         0.029782
# Simulation      0.074929
# Sports          0.058490
# Strategy        0.073284
# Name: Japan_Sales, dtype: float64

# %%
avg_sales_per_genre_in_other = video_game_sale.groupby('Genre')['Other_Sales'].mean()

# %%
avg_sales_per_genre_in_other
# Out:
# Genre
# Action          0.056881
# Adventure       0.013108
# Fighting        0.043289
# Misc            0.043843
# Platform        0.058869
# Puzzle          0.021877
# Racing          0.062596
# Role-Playing    0.040395
# Shooter         0.079485
# Simulation      0.036981
# Sports          0.057574
# Strategy        0.016761
# Name: Other_Sales, dtype: float64

# %%
avg_sales_df = pd.DataFrame({
    'North America': avg_sales_per_genre_in_na,
    'Europe': avg_sales_per_genre_in_europe,
    'Japan': avg_sales_per_genre_in_japan,
    'Other': avg_sales_per_genre_in_other,
})

# %%
regions = ['North America', 'Europe', 'Japan', 'Other']

plt.figure(figsize=(15, 12))  

for i, region in enumerate(regions, start=1):
    plt.subplot(2, 2, i)  
    avg_sales_df[region].sort_values(ascending=False).plot(kind='bar', color='#6B3333')
    plt.title(f'Average Sales per Genre in {region}')
    plt.xlabel('Genre')
    plt.ylabel('Average Sales (millions)')
    plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# North America (NA): Platform and Shooter genres dominate, while Strategy and Adventure underperform.
#
# Europe (EU): Shooter leads, followed by Platform and Racing; Strategy and Adventure trail behind.
#
# Japan (JP): Role-Playing is most popular, with low interest in Shooters and Adventure games.
#
# Other Regions: Shooter and Racing top the charts, while Strategy, Adventure, and Puzzle lag.

# %% [markdown]
# #
#
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align: center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Finding Average Sales Of Video Games Per Year In Regions</strong>
#   </h1>
# </div>

# %%
avg_sales_per_year_in_na = video_game_sale.groupby('Year')['North_America_Sales'].mean()

# %%
avg_sales_per_year_in_na
# Out:
# Year
# 1980    1.176667
# 1981    0.726087
# 1982    0.747778
# 1983    0.456471
# 1984    2.377143
# 1985    2.409286
# 1986    0.595238
# 1987    0.528750
# 1988    1.591333
# 1989    2.655882
# 1990    1.591250
# 1991    0.311220
# 1992    0.787674
# 1993    0.252000
# 1994    0.232645
# 1995    0.113333
# 1996    0.329886
# 1997    0.327855
# 1998    0.338681
# 1999    0.372959
# 2000    0.270745
# 2001    0.360954
# 2002    0.260784
# 2003    0.249794
# 2004    0.294086
# 2005    0.258098
# 2006    0.261032
# 2007    0.259101
# 2008    0.246106
# 2009    0.236792
# 2010    0.242037
# 2011    0.212148
# 2012    0.236534
# 2013    0.283462
# 2014    0.227534
# 2015    0.167459
# 2016    0.066257
# 2017    0.000000
# 2020    0.270000
# Name: North_America_Sales, dtype: float64

# %%
avg_sales_per_year_in_europe = video_game_sale.groupby('Year')['Europe_Sales'].mean()

# %%
avg_sales_per_year_in_europe
# Out:
# Year
# 1980    0.074444
# 1981    0.042609
# 1982    0.045833
# 1983    0.047059
# 1984    0.150000
# 1985    0.338571
# 1986    0.135238
# 1987    0.088125
# 1988    0.439333
# 1989    0.496471
# 1990    0.476875
# 1991    0.096341
# 1992    0.272326
# 1993    0.077500
# 1994    0.122975
# 1995    0.068037
# 1996    0.179696
# 1997    0.167197
# 1998    0.176517
# 1999    0.185414
# 2000    0.151146
# 2001    0.196867
# 2002    0.132376
# 2003    0.133948
# 2004    0.142366
# 2005    0.129872
# 2006    0.128214
# 2007    0.133372
# 2008    0.129132
# 2009    0.133885
# 2010    0.140469
# 2011    0.147280
# 2012    0.181313
# 2013    0.230403
# 2014    0.216603
# 2015    0.159137
# 2016    0.078246
# 2017    0.000000
# 2020    0.000000
# Name: Europe_Sales, dtype: float64

# %%
avg_sales_per_year_in_japan = video_game_sale.groupby('Year')['Japan_Sales'].mean()

# %%
avg_sales_per_year_in_japan
# Out:
# Year
# 1980    0.000000
# 1981    0.000000
# 1982    0.000000
# 1983    0.476471
# 1984    1.019286
# 1985    1.040000
# 1986    0.943333
# 1987    0.726875
# 1988    1.050667
# 1989    1.080000
# 1990    0.930000
# 1991    0.360488
# 1992    0.672326
# 1993    0.422167
# 1994    0.280909
# 1995    0.208904
# 1996    0.218403
# 1997    0.169100
# 1998    0.132032
# 1999    0.154852
# 2000    0.122550
# 2001    0.082697
# 2002    0.050374
# 2003    0.044129
# 2004    0.055981
# 2005    0.057991
# 2006    0.073145
# 2007    0.050200
# 2008    0.042199
# 2009    0.043249
# 2010    0.047327
# 2011    0.046690
# 2012    0.078992
# 2013    0.087161
# 2014    0.068034
# 2015    0.054919
# 2016    0.039971
# 2017    0.016667
# 2020    0.000000
# Name: Japan_Sales, dtype: float64

# %%
avg_sales_per_year_in_other = video_game_sale.groupby('Year')['Other_Sales'].mean()

# %%
avg_sales_per_year_in_other
# Out:
# Year
# 1980    0.013333
# 1981    0.006957
# 1982    0.008611
# 1983    0.008235
# 1984    0.050000
# 1985    0.065714
# 1986    0.091905
# 1987    0.012500
# 1988    0.066000
# 1989    0.088235
# 1990    0.087500
# 1991    0.018049
# 1992    0.038372
# 1993    0.014833
# 1994    0.018182
# 1995    0.012055
# 1996    0.029240
# 1997    0.031592
# 1998    0.029103
# 1999    0.029734
# 2000    0.033295
# 2001    0.047220
# 2002    0.032907
# 2003    0.033561
# 2004    0.063495
# 2005    0.043323
# 2006    0.053998
# 2007    0.064596
# 2008    0.057696
# 2009    0.052250
# 2010    0.047653
# 2011    0.047879
# 2012    0.057740
# 2013    0.072930
# 2014    0.069000
# 2015    0.048876
# 2016    0.022661
# 2017    0.000000
# 2020    0.020000
# Name: Other_Sales, dtype: float64

# %%
avg_sales_year_df = pd.DataFrame({
    'North America': avg_sales_per_year_in_na,
    'Europe': avg_sales_per_year_in_europe,
    'Japan': avg_sales_per_year_in_japan,
    'Other': avg_sales_per_year_in_other
})

# %%
regions = ['North America', 'Europe', 'Japan', 'Other']

plt.figure(figsize=(20, 14))  # large figure

for i, region in enumerate(regions, start=1):
    plt.subplot(2, 2, i)  # 2 rows x 2 cols layout
    avg_sales_year_df[region].plot(kind='line',
                                   color='#40373E', 
                                   marker = "o",
                                   linewidth=3)
    plt.title(f'Average Sales per Year in {region}')
    plt.xlabel('Year')
    plt.ylabel('Average Sales (millions)')
    plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# North America (NA): Peaked in 1989, then declined and stagnated, with slight recovery in 2020.
#
# Europe (EU): Peaked in early 1990s, stayed stable with a moderate rise around 2012–2014.
#
# Japan (JP): Dominated in the 1980s, but faced a long, steady decline post-1990.
#
# Other Regions: Saw late growth from the late 1990s, with steady sales peaking in 2008–2014.
#
# The dataset focuses on physical sales for console games, with some PC representation. It does not include modern digital-only ecosystems or mobile platforms, which became dominant post-2000. This is one of the main reasons for the apparent drop in sales in later years

# %% [markdown]
# #
#
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align: center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Global Sales Of Video Games</strong>
#   </h1>
# </div>

# %%
highest_sales_of_genre_global = video_game_sale.groupby("Genre").agg({"Global_Sales":"sum"}).sort_values("Global_Sales",ascending = False)
# Highest Sales of Genre Globaly

# %%
highest_sales_of_genre_global
# Out:
#               Global_Sales
# Genre
# Action             1722.84
# Sports             1309.24
# Shooter            1026.20
# Role-Playing        923.83
# Platform            829.13
# Misc                789.87
# Racing              726.76
# Fighting            444.05
# Simulation          389.98
# Puzzle              242.21
# Adventure           234.59
# Strategy            173.27

# %%
plt.figure(figsize= (12,8))
sns.barplot(data = highest_sales_of_genre_global,
           x =highest_sales_of_genre_global.index ,
           y = "Global_Sales",
           color = "#45214A",
           order = highest_sales_of_genre_global.index)
plt.title("Highest Sales of Genre Global")
plt.xlabel("Genre")
plt.ylabel("Average Sales(in million)")
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# ### Highest Sales of Genre Global
# Action games lead all genres globally with nearly 1750 million in average sales.
# Sports and Shooter genres follow closely, driven by popular franchises like FIFA, NBA, and Call of Duty.
# Genres like Puzzle, Strategy, and Adventure have relatively lower sales, indicating niche but consistent audiences.

# %%
highest_sales_of_platform_global = video_game_sale.groupby("Platform").agg({"Global_Sales":"sum"}).sort_values("Global_Sales",ascending = False)
# Highest Sales of Platform Globaly

# %%
highest_sales_of_platform_global
# Out:
#           Global_Sales
# Platform
# PS2            1233.46
# X360            969.60
# PS3             949.35
# Wii             909.81
# DS              818.91
# PS              727.39
# GBA             305.62
# PSP             291.71
# PS4             278.10
# PC              254.70
# GB              254.42
# XB              252.09
# NES             251.07
# 3DS             246.27
# N64             218.21
# SNES            200.05
# GC              197.14
# XOne            141.06
# 2600             86.57
# WiiU             81.86
# PSV              61.60
# SAT              33.59
# GEN              28.36
# DC               15.97
# SCD               1.87
# NG                1.44
# WS                1.42
# TG16              0.16
# 3DO               0.10
# GG                0.04
# PCFX              0.03

# %%
plt.figure(figsize= (12,8))
sns.barplot(data = highest_sales_of_platform_global,
           x =highest_sales_of_platform_global.index ,
           y = "Global_Sales",
           color = "#327355",
           order = highest_sales_of_platform_global.index)
plt.title("Highest Sales of Platform Global")
plt.xlabel("Platform")
plt.ylabel("Average Sales(in million)")
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# ### Highest Sales of Platform Global
# The PlayStation 2 (PS2) is the best-selling platform globally with sales above 1200 million.
# Consoles like Xbox 360, PS3, and Wii also have strong sales, highlighting the 7th generation’s dominance.
# Newer platforms like PS4 perform well, but older handhelds like GBA and DS also show significant longevity.

# %%
top20_publisher_global = video_game_sale.groupby("Publisher").agg({"Global_Sales":"sum"}).sort_values("Global_Sales",ascending = False).head(20)
# Highest Sale Of Publisher global

# %%
top20_publisher_global
# Out:
#                                         Global_Sales
# Publisher
# Nintendo                                     1784.43
# Electronic Arts                              1093.39
# Activision                                    721.41
# Sony Computer Entertainment                   607.28
# Ubisoft                                       473.54
# Take-Two Interactive                          399.30
# THQ                                           340.44
# Konami Digital Entertainment                  278.56
# Sega                                          270.70
# Namco Bandai Games                            253.65
# Microsoft Game Studios                        245.79
# Capcom                                        199.95
# Atari                                         146.77
# Square Enix                                   144.73
# Warner Bros. Interactive Entertainment        142.34
# Disney Interactive Studios                    118.76
# ...

# %%
plt.figure(figsize= (12,8))
sns.barplot(data = top20_publisher_global,
           x =top20_publisher_global.index ,
           y = "Global_Sales",
           color = "#7B6823",
           order = top20_publisher_global.index)
plt.title("Top 20 Publishers Global")
plt.xlabel("Publisher")
plt.ylabel("Average Sales(in million)")
plt.xticks(size = 8, rotation=90) 
plt.show()

# %% [markdown]
# ### Top 20 Publishers Global
# Nintendo leads all publishers with average global sales exceeding 1750 million units, far surpassing competitors.
# Electronic Arts and Activision follow, driven by consistent franchises like FIFA and Call of Duty.
# The top five publishers dominate the market, with a steep drop in sales after Ubisoft and Take-Two Interactive.

# %%
top20_game_sales_global = video_game_sale.groupby("Name").agg({"Global_Sales":"sum"}).sort_values("Global_Sales",ascending = False).head(20)
# Highest Sales of Individual Games Globaly

# %%
top20_game_sales_global
# Out:
#                                 Global_Sales
# Name
# Wii Sports                             82.74
# Grand Theft Auto V                     55.92
# Super Mario Bros.                      45.31
# Tetris                                 35.84
# Mario Kart Wii                         35.82
# Wii Sports Resort                      33.00
# Pokemon Red/Pokemon Blue               31.37
# Call of Duty: Modern Warfare 3         30.83
# New Super Mario Bros.                  30.01
# Call of Duty: Black Ops II             29.72
# Call of Duty: Black Ops                29.40
# Wii Play                               29.02
# New Super Mario Bros. Wii              28.62
# Duck Hunt                              28.31
# Call of Duty: Ghosts                   27.38
# Super Mario World                      26.07
# Call of Duty: Black Ops 3              25.32
# Call of Duty: Modern Warfare 2         25.09
# Nintendogs                             24.76
# Grand Theft Auto: San Andreas          23.86

# %%
plt.figure(figsize= (12,8))
sns.barplot(data = top20_game_sales_global,
           x =top20_game_sales_global.index ,
           y = "Global_Sales",
           color = "#D95555",
           order = top20_game_sales_global.index)
plt.title("Top 20 Individual Games Sales Global")
plt.xlabel("Name")
plt.ylabel("Average Sales(in million)")
plt.xticks(size = 8, rotation=90) 
plt.show()

# %% [markdown]
# ### Top 20 Individual Games Sales Global
# Wii Sports tops the list with over 80 million global sales, largely due to its bundling with the Wii console.
# Titles from Grand Theft Auto, Mario, and Call of Duty dominate the top rankings, showing franchise strength.
# Most top-selling games are from well-established series, indicating the impact of brand loyalty in game sales.

# %% [markdown]
# #
#
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align: center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Yearly Sales And Release Of Video Games</strong>
#   </h1>
# </div>

# %%
global_sales_per_year = video_game_sale.groupby("Year").agg({"Global_Sales":"sum"}).sort_values("Year")
# total global sales of video games in every year

# %%
global_sales_per_year
# Out:
#       Global_Sales
# Year
# 1980         11.38
# 1981         35.77
# 1982         28.86
# 1983         16.79
# 1984         50.36
# 1985         53.94
# 1986         37.07
# 1987         21.74
# 1988         47.22
# 1989         73.45
# 1990         49.39
# 1991         32.23
# 1992         76.16
# 1993         45.98
# 1994         79.17
# 1995         88.11
# 1996        199.15
# 1997        200.98
# 1998        256.47
# 1999        251.27
# 2000        201.56
# 2001        331.47
# 2002        395.52
# 2003        357.85
# 2004        414.01
# 2005        458.51
# 2006        521.04
# 2007        609.92
# 2008        678.90
# 2009        667.30
# 2010        600.29
# 2011        515.80
# 2012        363.49
# 2013        368.11
# 2014        337.03
# 2015        264.44
# 2016         70.90
# 2017          0.05
# 2020          0.29

# %%
plt.figure(figsize= (12,8))
sns.barplot(data = global_sales_per_year,
           x =global_sales_per_year.index ,
           y = "Global_Sales",
           color = "#634A00",
           order = global_sales_per_year.index)
plt.title("Global Sales of Video Game per Year")
plt.xlabel("Year")
plt.ylabel("Sales(in million)")
plt.xticks(size = 8, rotation=90) 
plt.show()

# %% [markdown]
# ### Global Sales of Video Games per Year
# Sales showed exponential growth from 1995 and peaked around 2008–2009 at nearly 700 million units.
# A consistent decline in global sales followed the peak years.
# This pattern mirrors the game release trends, suggesting saturation or market shifts post-2009.

# %%
#Genre of Game has Sold the Most in a Single Year
year_sale_group = video_game_sale.groupby(by=["Year", "Genre"])["Global_Sales"].sum().reset_index()
yearly_sales = year_sale_group.groupby(by=["Year"])["Global_Sales"].transform(max) == year_sale_group["Global_Sales"]
yearly_sales_max = year_sale_group[yearly_sales].reset_index(drop = True)

# %%
top_game_sale_yearly = yearly_sales_max.sort_values(by='Global_Sales', ascending=False).reset_index(drop=True)

# %%
top_game_sale_yearly
# Out:
#     Year         Genre  Global_Sales
# 0   2009        Action        139.36
# 1   2008        Action        136.39
# 2   2006        Sports        136.16
# 3   2013        Action        125.22
# 4   2012        Action        122.01
# 5   2011        Action        118.96
# 6   2010        Action        117.64
# 7   2007        Action        106.50
# 8   2014        Action         99.02
# 9   2002        Action         86.77
# 10  2005        Action         85.69
# 11  2004        Action         76.26
# 12  2015        Action         70.70
# 13  2003        Action         67.93
# 14  2001        Action         59.39
# 15  1999  Role-Playing         49.09
# 16  1996  Role-Playing         43.96
# 17  1985      Platform         43.17
# 18  1998        Sports         41.79
# 19  2000        Sports         41.19
# 20  1989        Puzzle         37.75
# 21  1997        Racing         31.91
# 22  1984       Shooter         31.10
# 23  1994      Platform         28.74
# ...

# %%
ordered_years = top_game_sale_yearly['Year'].astype(str).tolist()  

plt.figure(figsize=(16, 10))

g = sns.barplot(
    x='Year',
    y='Global_Sales',
    hue='Genre',
    data=top_game_sale_yearly,
    dodge=False,
    palette=(["#FFFF00","#00FFFF","#0000FF","#800080","#00FF00","#808000","#008000","#800000","#FFA500"]),
    order=ordered_years 
)

# Add count labels on top of bars
for p in g.patches:
    height = p.get_height()
    g.text(
        p.get_x() + p.get_width() / 2,
        height + 1,
        int(height),
        ha='center',
        va='bottom',
        fontsize=10,
        color='black'
    )

plt.title("Genre of Game has Sold the Most in a Single Year", fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel("Global Sales", fontsize=14)
plt.xticks(rotation=90)
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Genre of Game Sold the Most in a Single Year
# Action games consistently led global sales from 2004 to 2016, peaking above 130 million units.
# Sports games were top sellers in the 1990s and early 2000s, showing their historical popularity.
# The sales spike aligns with the high release volumes seen in the first chart, especially around 2008–2010.
# Post-2016, sales plummet dramatically, echoing the reduction in game releases.
# Despite genre diversity in earlier years, Action games dominate sales performance during the industry's peak.

# %%
# Top publisher by Count each year
top_publisher = video_game_sale[["Year", "Publisher"]]
top_publisher_data = top_publisher.groupby(by = ["Year", "Publisher"]).size().reset_index(name = "count")
top_publisher_data2 = top_publisher_data.groupby(by = ["Year"])["count"].transform(max) == top_publisher_data["count"]
top_publisher_count = top_publisher_data[top_publisher_data2].reset_index(drop = True)
top_publisher_count = top_publisher_count.drop_duplicates(subset=["Year", "count"], keep = "last").reset_index(drop = True)

# %%
top_publisher_count_sorted = top_publisher_count.sort_values(by='count', ascending=False).reset_index(drop=True)

# %%
top_publisher_count_sorted
# Out:
#     Year                     Publisher  count
# 0   2009                    Activision    121
# 1   2008               Electronic Arts    120
# 2   2005               Electronic Arts    117
# 3   2007               Electronic Arts    107
# 4   2006               Electronic Arts    102
# 5   2010                    Activision     89
# 6   2002               Electronic Arts     88
# 7   2011                       Ubisoft     87
# 8   2004               Electronic Arts     86
# 9   2012            Namco Bandai Games     85
# 10  2003               Electronic Arts     85
# 11  2014            Namco Bandai Games     69
# 12  2015            Namco Bandai Games     68
# 13  2013            Namco Bandai Games     63
# 14  2001               Electronic Arts     43
# 15  2016            Namco Bandai Games     40
# 16  1997   Sony Computer Entertainment     34
# 17  1999  Konami Digital Entertainment     32
# 18  2000   Sony Computer Entertainment     32
# ...

# %%
ordered_years = top_publisher_count_sorted['Year'].astype(str).tolist() 

plt.figure(figsize=(16, 10))

g = sns.barplot(
    x='Year',
    y='count',
    hue='Publisher',
    data=top_publisher_count_sorted,
    dodge=False,
    palette=(["#0000FF","#00FFFF","#800080","#FFFF00","#00FF00","#808000","#008000","#800000","#FFA500"]),
    order=ordered_years  
)

# Add count labels on top of bars
for p in g.patches:
    height = p.get_height()
    g.text(
        p.get_x() + p.get_width() / 2,
        height + 1,
        int(height),
        ha='center',
        va='bottom',
        fontsize=10,
        color='black'
    )

plt.title('Top Publisher by Count Each Year', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Game Count', fontsize=14)
plt.xticks(rotation=90)
plt.legend(title='Publisher', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top Publisher by Count Each Year
# Electronic Arts had a major presence in the 2000s, often releasing over 100 games annually.
# Nintendo dominated the 1980s and early 1990s as the most frequent publisher
# Sony Computer Entertainment emerged as a strong player from the late 1990s to mid-2000s.
# Activision and Ubisoft gained prominence post-2008, especially with action-focused titles.
# Publisher dominance shifts from Nintendo → Sony → EA → Ubisoft/Namco, indicating changing market leadership.

# %%
# Most Game Release in a Year
yearly_release_of_game = video_game_sale.groupby("Year").agg({"Name":"count"}).sort_values("Year")

# %%
yearly_release_of_game
# Out:
#       Name
# Year
# 1980     9
# 1981    46
# 1982    36
# 1983    17
# 1984    14
# 1985    14
# 1986    21
# 1987    16
# 1988    15
# 1989    17
# 1990    16
# 1991    41
# 1992    43
# 1993    60
# 1994   121
# 1995   219
# 1996   263
# 1997   289
# 1998   379
# 1999   338
# 2000   349
# 2001   482
# 2002   829
# 2003   775
# 2004   744
# 2005   936
# 2006  1008
# 2007  1201
# 2008  1428
# 2009  1431
# 2010  1257
# 2011  1136
# 2012   655
# 2013   546
# 2014   580
# 2015   614
# 2016   342
# 2017     3
# 2020     1

# %%
plt.figure(figsize= (12,8))
sns.barplot(data = yearly_release_of_game,
           x =yearly_release_of_game.index ,
           y = "Name",
           color = "#F29325",
           order = yearly_release_of_game.index)
plt.title("Most Games Release in Single Year")
plt.xlabel("Name")
plt.ylabel("Count of Games Released")
plt.xticks(size = 8, rotation=90) 
plt.show()

# %% [markdown]
# ### Most Games Released in a Single Year
# Game releases increased steadily from 1980, peaking sharply around 2008–2009.
# Post-2009, there is a visible decline in annual game releases.
# 2008 and 2009 were the most productive years with over 1,400 releases each.

# %%
# Genre of Game has Released the Most in a Single Year
max_year_data = video_game_sale.groupby(["Year", "Genre"]).size().reset_index(name = "count")
max_year_data2 = max_year_data.groupby(["Year"])["count"].transform(max) == max_year_data["count"]
year_max_genre = max_year_data[max_year_data2].reset_index(drop = True)
year_max_genre = year_max_genre.drop_duplicates(subset = ["Year", "count"], keep = "last").reset_index(drop = True)

# %%
top_genre_released = year_max_genre.sort_values(by='count', ascending=False).reset_index(drop=True)

# %%
top_genre_released
# Out:
#     Year         Genre  count
# 0   2009        Action    272
# 1   2012        Action    265
# 2   2015        Action    255
# 3   2011        Action    239
# 4   2010        Action    226
# 5   2008        Action    221
# 6   2007        Action    211
# 7   2005        Action    192
# 8   2002        Sports    188
# 9   2014        Action    186
# 10  2006        Action    184
# 11  2013        Action    148
# 12  2003        Action    144
# 13  2004        Action    125
# 14  2016        Action    118
# 15  2001        Sports     96
# 16  2000        Sports     81
# 17  1998        Sports     70
# 18  1999        Sports     62
# 19  1996        Sports     52
# 20  1997        Sports     46
# 21  1995        Sports     29
# 22  1981        Action     25
# 23  1994        Sports     22
# 24  1982        Action     18
# 25  1993      Platform     11
# 26  1991        Sports      7
# 27  1983        Action      7
# 28  1992      Fighting      7
# 29  1986      Platform      6
# ...

# %%
ordered_years = top_genre_released['Year'].astype(str).tolist()  

plt.figure(figsize=(14, 8))

g = sns.barplot(
    x='Year',
    y='count',
    hue='Genre',
    data=top_genre_released,
    dodge=False,
    palette=(["#0000FF","#00FFFF","#800080","#FFFF00","#00FF00","#808000","#008000","#800000","#FFA500"]),
    order=ordered_years  
)

# Add count labels on top of bars
for p in g.patches:
    height = p.get_height()
    g.text(
        p.get_x() + p.get_width() / 2,
        height + 1,
        int(height),
        ha='center',
        va='bottom',
        fontsize=10,
        color='black'
    )

plt.title("Top Genre of Game has Released in a Single Year", fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel("Number of Games Released", fontsize=14)
plt.xticks(rotation=90)
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Genre of Game Released the Most in a Single Year
# The Action genre dominates most years from 2004 to 2016 in terms of the number of games released.
# A significant spike in game releases occurred between 2007 and 2010, with over 250 Action games in a single year.
# Early years (1980s–1990s) show more diversity with genres like Sports, Platform, and Puzzle leading.
# Game production drastically decreased after 2016.
# The drop in 2017–2020 suggests changes in the industry, possibly due to digital transition or fewer physical releases.

# %% [markdown]
# # Revenue By Each Region
#
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align: center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Revenue By Each Region</strong>
#   </h1>
# </div>

# %%
# Total Revenue by Region
revenue_by_region = video_game_sale[["North_America_Sales", "Europe_Sales", "Japan_Sales", "Other_Sales"]].sum()

# %%
revenue_by_region
# Out:
# North_America_Sales    4327.65
# Europe_Sales           2406.69
# Japan_Sales            1284.27
# Other_Sales             788.91
# dtype: float64

# %%
plt.figure(figsize=(8, 8))
plt.pie(revenue_by_region,
        labels=revenue_by_region.index,
        autopct='%1.1f%%',
        colors=["#D6D58E", "#005C53", "#9FC131", "#DBF227"],
        startangle=140,
        wedgeprops={"edgecolor": "white", "linewidth": 2})

plt.title("Video Game Sales Distribution by Region", fontsize=16)
plt.axis("equal")  # Equal aspect ratio makes the pie round.
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Video Game Sales Distribution by Region
# North America dominates global sales with nearly half (49.1%) of total sales.
# Europe follows with 27.3%, while Japan contributes 14.6%.
# The remaining 9% is from all other regions combined, showing heavy market concentration in NA and Europe.

# %% [markdown]
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align: center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Ranking Of Video Games</strong>
#   </h1>
# </div>

# %%
top_10_game_rank = video_game_sale[["Rank", "Name", "Platform", "Publisher"]].head(10).set_index("Rank")

# %%
top_10_game_rank
# Out:
#                            Name Platform Publisher
# Rank
# 1                    Wii Sports      Wii  Nintendo
# 2             Super Mario Bros.      NES  Nintendo
# 3                Mario Kart Wii      Wii  Nintendo
# 4             Wii Sports Resort      Wii  Nintendo
# 5      Pokemon Red/Pokemon Blue       GB  Nintendo
# 6                        Tetris       GB  Nintendo
# 7         New Super Mario Bros.       DS  Nintendo
# 8                      Wii Play      Wii  Nintendo
# 9     New Super Mario Bros. Wii      Wii  Nintendo
# 10                    Duck Hunt      NES  Nintendo

# %%
bottom_10_game_rank = video_game_sale[["Rank", "Name", "Platform", "Publisher"]].tail(10).set_index("Rank")

# %%
bottom_10_game_rank
# Out:
#                                                     Name Platform  \
# Rank
# 16591                                   Mega Brain Boost       DS
# 16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16594                                Myst IV: Revelation       PC
# 16595                                           Plushees       DS
# 16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16597                      Men in Black II: Alien Escape       GC
# 16598   SCORE International Baja 1000: The Official Game      PS2
# 16599                                         Know How 2       DS
# 16600                                   Spirits & Spells      GBA
#
#                    Publisher
# Rank
# 16591  Majesco Entertainment
# 16592        dramatic create
# 16593     Falcom Corporation
# 16594                Ubisoft
# 16595              Destineer
# 16596                  Kemco
# ...

# %% [markdown]
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align: center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Final Insights</strong>
#   </h1>
# </div>

# %% [markdown]
# 1: Action remains a consistently dominant genre in yearly releases, reflecting developer interest and market demand.
#
# 2: Although Action is released the most, Shooter games achieve the highest single-year sales, possibly due to
# blockbuster franchises (like Call of Duty).
#
# 3: Nintendo's long-term IPs (Mario, Zelda, Pokémon) provide consistent high sales globally.
#
# 4: A mix of casual (e.g., Wii Sports) and core gamer-focused titles dominate top sales globally.
#
# 5: Platforms with long lifespans and broad appeal (casual + hardcore gamers) achieve top sales.
#
# 6: Action has both high release frequency and high global sales, indicating strong overall market dominance.
#
# 7: A sharp rise in game development during late 2000s possibly due to indie boom and multiple platforms being active (PS3, Xbox 360, Wii).
#
# 8: EA’s large volume of annual releases (sports games, sequels) helps it dominate in count, while Nintendo combines quality with volume.
#
# 9: NA leads likely due to console-heavy market, high disposable income, and strong franchise support.

# %% [markdown]
# <div style="background: linear-gradient(to right, #D64AD9, #D771D9, #371F8C, #141E59, #55A6D9); padding: 25px; border-radius: 10px; text-align:
# center;">
#   <h1 style="color: White; font-size: 24px; font-weight: bold; margin: 0;">
#     <strong>Recommendation</strong>
#   </h1>
# </div>

# %% [markdown]
# Study genre trends to release games in genres that are peaking or consistently strong, such as Action or Shooter.
#
# Build or acquire strong intellectual properties to increase long-term sales potential and brand loyalty.
#
# Prioritize development for platforms with the largest user bases to maximize reach and profitability.
#
# Consider remakes, sequels, or spin-offs of best-selling games to tap into established audiences
#
# Time releases around new console launches, holiday seasons, or global events that boost engagement.
#
# Tailor games and marketing strategies for specific regions—e.g., localized content for Japan or sports-heavy themes for North America.
#
# While focusing on top-performing genres, explore opportunities in emerging or underrepresented genres to stand out.
